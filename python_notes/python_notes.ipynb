# %% [markdown]
# # Python Notes
#
# ## Introduction
#
# ## Installation and Setup
#
# ### Virtual Environment
#
# ## Hello World

# %% [markdown]
# ## Basics
#
# ### Syntax
#
# ### Variables
#
# ### Data Types
#
# #### Type Casting
#
# ### Operators
#
# ### User Input

# %% [markdown]
# ## Control Flow
#
# ### if elif else
#
# ### match case
#
# ### for and for else loop
#
# ### while loop
#
# ### break, continue, pass

# %% [markdown]
# ## string

# %% [markdown]
# ## list

# %% [markdown]
# ## tuple

# %% [markdown]
# ## set

# %% [markdown]
# ## dictionary

# %% [markdown]
# ## array

# %% [markdown]
# ## Functions

# %% [markdown]
# ## OOP
#
# ### Class
#
# ### Method

# %% [markdown]
# ## Error and Exception Handling

# %% [markdown]
# ## Iterator, Generator and Decorator

# %% [markdown]
# ## Documentation

# %% [markdown]
# ## Sample Usecases

# %% [markdown]
# ### Handling text files

# %% [markdown]
# ### Handling csv files using pandas

# %% [markdown]
# ### Multithreading

# %% [markdown]
# ### Regular expressions

# %% [markdown]
# ### Native GUI
#
# #### Create simple GUI using pysimplegui

# %% [markdown]
# ### Browser based user interfaces
#
# #### Create helloworld user interface page using Dash

# %% [markdown]
# ### Open images / Play video using opencv

# %% [markdown]
# ### Creating python packages using poetry

# %% [markdown]
# ### Create python tests using pytest
#
# ### Create HTML test reports using pytest-html
